# %% [markdown]
# First Example of Matplotlib

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x,y)
print("This is a simple line graph")
plt.show()
# Out:
# This is a simple line graph

# %% [markdown]
# Second Example of matplotlib

# %%
import matplotlib.pyplot as plt

x = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
y= [10,15,7,20,12,5,25]

plt.plot(x,y)
plt.title('Bakery sales this week')

plt.xlabel('Days of The week')
plt.ylabel('Sales Per Day')

plt.show()

# %% [markdown]
# Example using Object oriented API

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

fig, ax = plt.subplots(figsize=(6,4))

ax.plot(x, y, marker='o', color='blue', label='Sales')
ax.set_title("Monthly Sales")
ax.set_xlabel("Month")
ax.set_ylabel("Revenue")
ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# pyplot Function their Syntax and Example:

# %%
# syntax: x and y is mandatory others are optional
# 1. plt.plot(x,y, color="color" ,linestyle="line_style", linewidth=value,marker="marker symbol",label="label name"

# Example:
import matplotlib.pyplot as plt

months = [1,2,3,4,5,6,7]
sales = [20000,30000,12000,4000,34000,1100,100000]

plt.plot(months,sales,color='blue',linestyle='--',linewidth=2,marker='o',label='2026 sales data')
# labeling
plt.xlabel("Months")
plt.ylabel("Sales Per Month")
# for title
plt.title("Monthly Sales Data Report")
# legend : it makes a box
plt.legend()
# grid(color="colorname",linestyle='line_style',linewidth:value) : It draw horizontal line or vertical line on background of of graph
plt.grid(color='gray',linestyle=':',linewidth=1)

plt.show()

# %% [markdown]
# Plotting Charts

# %% [markdown]
# BAR CHART

# %%
# syntax:
#plt.bar(x, height, color="colorname",width=value,label="label name")
# vertical bar chart

import matplotlib.pyplot as plt

product = ['A','B','C','D','E']
sales= [1000,1500,700,1200,1100]

plt.bar(product,sales,color='orange',label='2025 sales')

plt.xlabel('Products')
plt.ylabel('Sales')

plt.title('Product Sales Comparision')

plt.legend()
plt.show()

# %%
# Horizontal bar chart

import matplotlib.pyplot as plt

product = ['A','B','C','D','E']
sales= [1000,1500,700,1200,1100]

plt.barh(product,sales,color='orange',label='2025 sales')

plt.ylabel('Products')
plt.xlabel('Sales')

plt.title('Product Sales Comparision')

plt.legend()
plt.show()

# %% [markdown]
# Multiple Bar Charts (Side-by-Side)

# %%
import numpy as np
import matplotlib.pyplot as plt

names = ['A', 'B', 'C']
x = np.arange(len(names))

sales = [20, 35, 30]
profit = [15, 25, 20]

plt.bar(x - 0.2, sales, width=0.4, label='Sales')
plt.bar(x + 0.2, profit, width=0.4, label='Profit')

plt.xticks(x, names)
plt.legend()
plt.show()

# %% [markdown]
# Basic bar chart with value label

# %%
import matplotlib.pyplot as plt

names = ['A', 'B', 'C','D','E']
values = [20, 35, 30, 50,10]

#Returns a container of bar objects.
bars = plt.bar(names, values,color='green')

for bar in bars:
    #Gets the value (height) of each bar.
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        height,
        ha='center',
        va='bottom'
    )

plt.title("Bar Chart with Labels")
plt.show()

# %% [markdown]
# Bar Chart with Labels by using (Object Oriented API)

# %%
import matplotlib.pyplot as plt

names=['A','B','C','D','E']
values= [20, 45, 35, 50,10]


fig, ax = plt.subplots()

bars = ax.bar(names, values, color='skyblue')

for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width()/2,   # bar.get_x() gives the x-position of the LEFT edge of the bar.
                                           # bar.get_width() gives the total width of the bar. bar.
        bar.get_height(),
        bar.get_height(),
        ha='center',
        va='bottom'
    )

ax.set_title("Bar Chart with Value Labels")
plt.show()



"""
# Explanation why we divide by 2
bar.get_X() = 1.0
bar.get_width()= 0.4

bar.get_X() + bar.get_width()/2
    1.0   + (0.4/2)
    =1.2
"""
# Out:
# '\n# Explanation why we divide by 2\nbar.get_X() = 1.0\nbar.get_width()= 0.4\n\nbar.get_X() + bar.get_width()/2\n    1.0   + (0.4/2)\n    =1.2\n'

# %% [markdown]
# PIE CHART

# %%
import matplotlib.pyplot as plt

regions = ['North','South',"East",'West']
revenue = [3000,2000,1500,1000]

explode = [0.1, 0, 0, 0]

plt.pie(revenue,labels=regions,autopct='%1.1f%%',colors=['gold','skyblue','lightgreen','coral'] , explode=explode)
plt.title("Revenue Contribution by Regions")

plt.show()

# %% [markdown]
# Example of Pie Chart using (OO API)

# %%
import matplotlib.pyplot as plt

data = [40,30,20,10]
labels= ['Python','JavaScript',"Java","C"]

explode = [0.1,0,0,0]

fig , ax = plt.subplots()

ax.pie(data,labels=labels,autopct="%1.1f%%",colors=['orange','blue','green','coral'],explode=explode)

ax.set_title("Pie chart using OO API")

plt.show()

# %% [markdown]
# Histogram Chart

# %%
#Syntax:
#plt.hist(data,bins=value,color="color_name",edgecolor="color_name")
# bins means how many groups/ranges divide data
# In this example bins are 6 means it divide marks in 6 groups

import matplotlib.pyplot as plt

Marks = [50,45,67,30,22,89,58,85,75,67,56,57,48,90,46,89,66,88,99]

plt.hist(Marks,bins=6,color="purple",edgecolor="black")
plt.title("Student Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# Scatter Plot

# %%
#syntax:
# plt.scatter(x,y,color="color_name",marker="marker_style",label= "label name",s=value of size of dots)

import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5]   # study hours
marks = [40, 50, 60, 70, 80]  # marks

plt.scatter(study_hours,marks,color="blue",marker="o",label="Student Data")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Multiple Scatter Datasets

# %%
import matplotlib.pyplot as plt

study_hours= [1,2,3,4,5,6,7,8]
section_A_Marks =[80,75,78,90,88,76,87,95]
section_B_Marks = [55,66,56,45,55,60,65,59]

plt.scatter(study_hours,section_A_Marks,color="blue",label="Section A")
plt.scatter(study_hours,section_B_Marks,color="orange",label="Section B")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Comparison of Two Section A and B")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Example using Mutiple Datasets

# %% [markdown]
# 1. Multiple Lines on One Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]
y2 = [15, 25, 35, 45]

plt.plot(x, y1, label="Dataset 1")
plt.plot(x, y2, label="Dataset 2")

plt.legend()
plt.show()

# %% [markdown]
# 2. Multiple Scatter Datasets

# %%
import matplotlib.pyplot as plt

study_hours= [1,2,3,4,5,6,7,8]
section_A_Marks =[80,75,78,90,88,76,87,95]
section_B_Marks = [55,66,56,45,55,60,65,59]

plt.scatter(study_hours,section_A_Marks,color="blue",label="Section A")
plt.scatter(study_hours,section_B_Marks,color="orange",label="Section B")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Comparison of Two Section A and B")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Subplots Example :

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(1,2,figsize = (10,5))

x =[1,2,3,4,5]
y= [10,20,30,40,50]

ax[0].plot(x,y,color="blue")
ax[0].set_title("Line chart")

ax[1].bar(x,y,color="green")
ax[1].set_title("Bar chart")

# this is used for set the title for figure(window)
fig.suptitle("Comparison of Line Chart and Bar Chart")

# this is used for fixes the labels and title of charts
plt.tight_layout()
plt.show()

# %% [markdown]
# Save Graph and Charts

# %%
import matplotlib.pyplot as plt

product = ['A','B','C','D','E']
sales= [1000,1500,700,1200,1100]

plt.bar(product,sales,color='orange',label='2025 sales')

plt.xlabel('Products')
plt.ylabel('Sales')

plt.title('Product Sales Comparision')

plt.legend()

# for saving in a specific folder you write foldername/filename.extension
plt.savefig("Bar_Chart.png", dpi= 300, bbox_inches='tight')
plt.show()
